# %% [markdown]
# <a href="https://colab.research.google.com/github/asifbillah845-coder/ml-Internship--fyrank/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/asifbillah845-coder/ml-Internship--fyrank/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row = one what, over which dates? State it, then verify it below.
#
# Unit of Analysis: One row represents a single web page (URL). Time Window: Data is aggregated over a daily period (one day per record).
#
# This means each row contains metrics (like clicks, impressions, CTR) for a specific page on a specific date. I will verify this by checking if each combination of page and date appears only once in the dataset.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Sort every field you plan to touch into these four buckets. Excluded needs a why.
#
# Features (inputs for model):
#
# Impressions Clicks Position
#
# Label (target variable):
#
# CTR (Click Through Rate)
#
# Context (useful but not predictive directly):
#
# Date (helps understand trends over time) Page / Query (identifies the content source)
#
# Excluded Fields:
#
# Any ID columns (like row_id) → because they don’t add predictive value Duplicate or constant columns → because they don’t help the model learn patterns

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Every claim above gets a query cell here. A contract claim without a query next to it is a guess.
#
# Grain Check: Each row should represent a unique combination of Page and Date. This can be verified by grouping data by page and date and ensuring no duplicates exist.
#
# Counts Check: Total number of rows should match expected combinations of pages and dates. I will count total rows and unique pages/dates to confirm consistency.
#
# Missing Values Check: I will check for null or missing values in key columns like Clicks, Impressions, CTR, and Position to ensure data quality.
#
# Time Window Check: I will verify that dates are continuous and fall within the expected time range without unexpected gaps or overlaps.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.
#
# This dataset has several limitations:
#
# It does not capture user intent or behavior beyond clicks and impressions. Early data may be incomplete (e.g., only from Search Console), which can create imbalance. Time windows may overlap or have gaps, affecting trend analysis. External factors (like SEO changes, competition, or seasonality) are not included. The dataset cannot fully explain why CTR changes, only what changed.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
