# %% [markdown]
# <a href="https://colab.research.google.com/github/asifbillah845-coder/ml-Internship--fyrank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/asifbillah845-coder/ml-Internship--fyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Selected Lane: Refresh / Content Opportunity Scoring
#
# I selected the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that should be reviewed and updated first. Instead of checking every page manually, I want to use data to prioritize pages that have the greatest opportunity for improvement. This project can help content and SEO teams make faster and more evidence-based decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question
# Which webpages should be reviewed and updated first to improve their SEO performance and content quality?
#
# Decision
# The decision is to identify and prioritize the webpages that have the highest potential for improvement.
#
# Action
# The SEO or content team will review, update, and optimize the selected webpages based on the recommendations.
#
# Cost of a Wrong Recommendation
# If the wrong pages are selected, the team may spend time updating pages that do not need improvement while missing pages that could significantly increase traffic and user engagement. This results in wasted effort and missed opportunities.
#
# Why Machine Learning Can Help
# Large websites may contain hundreds or thousands of webpages. Reviewing every page manually is slow and inefficient. Machine learning can analyze historical data, identify patterns, and rank pages based on their improvement potential, helping teams make faster and more data-driven decisions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("/content/refresh_queue_sample (1).csv")

# Basic statistics
print("Total pages:", len(df))
print("Average Refresh Score:", round(df["final_refresh_score"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 2))
# Out:
# Total pages: 200
# Average Refresh Score: 77.95
# Average CTR: 0.16

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # **What this project can claim**
# This project can identify patterns in the available website data.
# It can rank webpages based on their potential need for content refresh.
# It can provide decision support to help SEO and content teams prioritize which pages to review first.
# The recommendations are based on historical data and observed trends.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
